# %% [markdown]
# <a href="https://colab.research.google.com/github/Anup12year/Anup12year/blob/main/Data_Sampling(Project_110).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-85edb1d4-83a3-47c5-9e76-5d9ac7b70ed4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85edb1d4-83a3-47c5-9e76-5d9ac7b70ed4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving medium_data.csv to medium_data.csv

# %%
import plotly.figure_factory as ff
import statistics
import random
import pandas as pd
import csv

df = pd.read_csv("medium_data.csv")
data = df["reading_time"].tolist()
fig = ff.create_distplot([data], ["reading_time"], show_hist=False)
fig.show()
print("population mean: ",statistics.mean(data))
def random_set_of_mean(counter):
    dataset = []
    for i in range(0, counter):
        random_index= random.randint(0,len(data))
        value = data[random_index]
        dataset.append(value)
    mean = statistics.mean(dataset)
    return mean

def show_fig(mean_list):
    df = mean_list
    fig = ff.create_distplot([df], ["reading_time"], show_hist=False)
    fig.show()

def setup():
    mean_list = []
    for i in range(0,100):
        set_of_means= random_set_of_mean(10)
        mean_list.append(set_of_means)
    show_fig(mean_list)
    print("sampling mean: ", statistics.mean(mean_list))
setup()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e04f820c-334a-40b7-9632-a9f45304de03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e04f820c-334a-40b7-9632-a9f45304de03")) {                    Plotly.newPlot(                        "e04f820c-334a-40b7-9632-a9f45304de03",                        [{"legendgroup":"reading_time","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"reading_time","showlegend":true,"x":[0.0,0.11,0.22,0.33,0.44,0.55,0.66,0.77,0.88,0.99,1.1,1.21,1.32,1.43,1.54,1.65,1.76,1.87,1.98,2.09,2.2,2.31,2.42,2.53,2.64,2.75,2.86,2.97,3.08,3.19,3.3,3.41,3.52,3.63,3.74,3.85,3.96,4.07,4.18,4.29,4.4,4.51,4.62,4.73,4.84,4.95,5.06,5.17,5.28,5.39,5.5,5.61,5.72,5.83,5.94,6.05,6.16,6.27,6.38,6.49,6.6,6.71,6.82,6.93,7.04,7.15,7.26,7.37,7.48,7.59,7.7,7.81,7.92,8.03,8.14,8.25,8.36,8.47,8.58,8.69,8.8,8.91,9.02,9.13,9.24,9.35,9.46,9.57,9.68,9.79,9.9,10.01,10.12,10.23,10.34,10.45,10.56,10.67,10.78,10.89,11.0,11.11,11.22,11.33,11.44,11.55,11.66,11.77,11.88,11.99,12.1,12.21,12.32,12.43,12.54,12.65,12.76,12.87,12.98,13.09,13.2,13.31,13.42,13.53,13.64,13.75,13.86,13.97,14.08,14.19,14.3,14.41,14.52,14.63,14.74,14.85,14.96,15.07,15.18,15.29,15.4,15.51,15.62,15.73,15.84,15.95,16.06,16.17,16.28,16.39,16.5,16.61,16.72,16.83,16.94,17.05,17.16,17.27,17.38,17.49,17.6,17.71,17.82,17.93,18.04,18.15,18.26,18.37,18.48,18.59,18.7,18.81,18.92,19.03,19.14,19.25,19.36,19.47,19.58,19.69,19.8,19.91,20.02,20.13,20.24,20.35,20.46,20.57,20.68,20.79,20.9,21.01,21.12,21.23,21.34,21.45,21.56,21.67,21.78,21.89,22.0,22.11,22.22,22.33,22.44,22.55,22.66,22.77,22.88,22.99,23.1,23.21,23.32,23.43,23.54,23.65,23.76,23.87,23.98,24.09,24.2,24.31,24.42,24.53,24.64,24.75,24.86,24.97,25.08,25.19,25.3,25.41,25.52,25.63,25.74,25.85,25.96,26.07,26.18,26.29,26.4,26.51,26.62,26.73,26.84,26.95,27.06,27.17,27.28,27.39,27.5,27.61,27.72,27.83,27.94,28.05,28.16,28.27,28.38,28.49,28.6,28.71,28.82,28.93,29.04,29.15,29.26,29.37,29.48,29.59,29.7,29.81,29.92,30.03,30.14,30.25,30.36,30.47,30.58,30.69,30.8,30.91,31.02,31.13,31.24,31.35,31.46,31.57,31.68,31.79,31.9,32.01,32.12,32.23,32.34,32.45,32.56,32.67,32.78,32.89,33.0,33.11,33.22,33.33,33.44,33.55,33.66,33.77,33.88,33.99,34.1,34.21,34.32,34.43,34.54,34.65,34.76,34.87,34.98,35.09,35.2,35.31,35.42,35.53,35.64,35.75,35.86,35.97,36.08,36.19,36.3,36.41,36.52,36.63,36.74,36.85,36.96,37.07,37.18,37.29,37.4,37.51,37.62,37.73,37.84,37.95,38.06,38.17,38.28,38.39,38.5,38.61,38.72,38.83,38.94,39.05,39.16,39.27,39.38,39.49,39.6,39.71,39.82,39.93,40.04,40.15,40.26,40.37,40.48,40.59,40.7,40.81,40.92,41.03,41.14,41.25,41.36,41.47,41.58,41.69,41.8,41.91,42.02,42.13,42.24,42.35,42.46,42.57,42.68,42.79,42.9,43.01,43.12,43.23,43.34,43.45,43.56,43.67,43.78,43.89,44.0,44.11,44.22,44.33,44.44,44.55,44.66,44.77,44.88,44.99,45.1,45.21,45.32,45.43,45.54,45.65,45.76,45.87,45.98,46.09,46.2,46.31,46.42,46.53,46.64,46.75,46.86,46.97,47.08,47.19,47.3,47.41,47.52,47.63,47.74,47.85,47.96,48.07,48.18,48.29,48.4,48.51,48.62,48.73,48.84,48.95,49.06,49.17,49.28,49.39,49.5,49.61,49.72,49.83,49.94,50.05,50.16,50.27,50.38,50.49,50.6,50.71,50.82,50.93,51.04,51.15,51.26,51.37,51.48,51.59,51.7,51.81,51.92,52.03,52.14,52.25,52.36,52.47,52.58,52.69,52.8,52.91,53.02,53.13,53.24,53.35,53.46,53.57,53.68,53.79,53.9,54.01,54.12,54.23,54.34,54.45,54.56,54.67,54.78,54.89],"xaxis":"x","y":[0.0005586832361452941,0.0007065712390503667,0.0008969261193547522,0.0011433994751080198,0.0014641312631194685,0.0018833547769036454,0.002432920776999478,0.0031529754665996644,0.004090911459494481,0.005298022629265647,0.006824120461679852,0.008711547382597258,0.010991088622807394,0.013682581777044343,0.016801977496001805,0.020374092172243792,0.024446932622671908,0.029100629458682286,0.034443390345679385,0.040589736341369,0.0476225848950604,0.05 ...
# population mean:  6.134910878918254
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3d30e5f6-7425-4239-953e-d8c43c2cb399" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d30e5f6-7425-4239-953e-d8c43c2cb399")) {                    Plotly.newPlot(                        "3d30e5f6-7425-4239-953e-d8c43c2cb399",                        [{"legendgroup":"reading_time","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"reading_time","showlegend":true,"x":[4.3,4.3073999999999995,4.3148,4.3222,4.3296,4.337,4.3444,4.3518,4.3591999999999995,4.3666,4.374,4.3814,4.3888,4.396199999999999,4.4036,4.411,4.4184,4.4258,4.4332,4.4406,4.4479999999999995,4.4554,4.4628,4.4702,4.4776,4.484999999999999,4.4924,4.4998,4.5072,4.5146,4.522,4.5294,4.5367999999999995,4.5442,4.5516,4.559,4.5664,4.573799999999999,4.5812,4.5886,4.596,4.6034,4.6108,4.6182,4.6255999999999995,4.633,4.6404,4.6478,4.6552,4.662599999999999,4.67,4.6774,4.6848,4.6922,4.6996,4.707,4.7143999999999995,4.7218,4.7292,4.7366,4.744,4.7514,4.7588,4.7661999999999995,4.7736,4.781,4.7884,4.7958,4.8032,4.8106,4.818,4.8254,4.8328,4.840199999999999,4.8476,4.8549999999999995,4.8624,4.8698,4.8772,4.8846,4.8919999999999995,4.8994,4.9068,4.9142,4.9216,4.929,4.9364,4.9437999999999995,4.9512,4.9586,4.966,4.9734,4.9808,4.9882,4.9956,5.003,5.0104,5.0178,5.0252,5.0325999999999995,5.04,5.0474,5.0548,5.0622,5.069599999999999,5.077,5.0844,5.0918,5.0992,5.1066,5.114,5.1213999999999995,5.1288,5.1362,5.1436,5.151,5.1584,5.1658,5.1732,5.1806,5.188,5.1954,5.2028,5.2101999999999995,5.2176,5.225,5.2324,5.2398,5.247199999999999,5.2546,5.262,5.2694,5.2768,5.2842,5.2916,5.2989999999999995,5.3064,5.3138,5.3212,5.3286,5.336,5.3434,5.3508,5.3582,5.3656,5.372999999999999,5.3804,5.3877999999999995,5.3952,5.4026,5.41,5.4174,5.424799999999999,5.4322,5.4396,5.447,5.4544,5.4618,5.4692,5.4765999999999995,5.484,5.4914,5.498799999999999,5.5062,5.5136,5.521,5.5283999999999995,5.5358,5.5432,5.5506,5.558,5.5654,5.5728,5.5802,5.5876,5.595,5.602399999999999,5.6098,5.6172,5.6246,5.632,5.6394,5.6468,5.6541999999999994,5.6616,5.669,5.6764,5.6838,5.6912,5.6986,5.7059999999999995,5.7134,5.7208000000000006,5.7282,5.7356,5.743,5.7504,5.7578,5.7652,5.7726,5.779999999999999,5.7874,5.7948,5.8022,5.8096,5.817,5.8244,5.8318,5.8392,5.8466000000000005,5.854,5.8614,5.8688,5.8762,5.8835999999999995,5.891,5.8984,5.9058,5.9132,5.9206,5.928,5.9354,5.9428,5.9502,5.9576,5.965,5.9724,5.9798,5.9872,5.9946,6.002,6.009399999999999,6.0168,6.0241999999999996,6.0316,6.039,6.0464,6.0538,6.0611999999999995,6.0686,6.076,6.0834,6.0908,6.0982,6.1056,6.1129999999999995,6.1204,6.1278,6.135199999999999,6.1426,6.15,6.1574,6.1648,6.1722,6.1796,6.186999999999999,6.1944,6.2018,6.2092,6.2166,6.224,6.2314,6.2387999999999995,6.2462,6.2536000000000005,6.261,6.2684,6.2758,6.2832,6.2905999999999995,6.298,6.305400000000001,6.3128,6.3202,6.3276,6.335,6.3424,6.3498,6.357200000000001,6.364599999999999,6.372,6.3794,6.3868,6.3942,6.4016,6.409,6.416399999999999,6.4238,6.4312000000000005,6.438599999999999,6.446,6.4534,6.4608,6.4681999999999995,6.4756,6.483,6.490399999999999,6.4978,6.5052,6.5126,6.52,6.5274,6.534800000000001,6.5422,6.5496,6.557,6.5644,6.5718,6.5792,6.5866,6.593999999999999,6.6014,6.6088000000000005,6.6162,6.6236,6.631,6.6384,6.6457999999999995,6.6532,6.6606,6.667999999999999,6.6754,6.6828,6.6902,6.6975999999999996,6.705,6.7124,6.7198,6.7272,6.7346,6.742,6.7494,6.7568,6.764200000000001,6.771599999999999,6.779,6.7864,6.7938,6.8012,6.8086,6.816,6.8233999999999995,6.8308,6.8382000000000005,6.845599999999999,6.853,6.8604,6.8678,6.8751999999999995,6.8826,6.89,6.897399999999999,6.9048,6.9122,6.919599999999999,6.927,6.9344,6.941800000000001,6.9492,6.9566,6.964,6.9714,6.9788,6.9862,6.9936,7.0009999999999994,7.0084,7.0158000000000005,7.0232,7.0306,7.038,7.0454,7.05 ...
# sampling mean:  5.982
